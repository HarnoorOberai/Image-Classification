# %% [markdown]
# <a href="https://colab.research.google.com/github/HarnoorOberai/Image-Classification/blob/master/HarnoorSinghOberai__190753898__VGG16(CIFAR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import warnings
warnings.filterwarnings('ignore')

from keras.models import Model
from keras.utils import plot_model
from keras import regularizers
from keras import backend as K
from keras.layers import Input,Flatten, Dense,Dropout,BatchNormalization, concatenate
from keras.layers.convolutional import Conv2D,MaxPooling2D,AveragePooling2D
# Out:
# Using TensorFlow backend.

# %%
NB_CLASS=100
LEARNING_RATE=0.01
MOMENTUM=0.9
ALPHA=0.0001
BETA=0.75
GAMMA=0.1
DROPOUT=0.4
WEIGHT_DECAY=0.0005
LRN2D_NORM=True
DATA_FORMAT='channels_last' # Theano:'channels_first' Tensorflow:'channels_last'
USE_BN=True
IM_WIDTH=32
IM_HEIGHT=32
EPOCH=50

# %%
def conv2D_lrn2d(x,filters,kernel_size,padding='same',activation='relu',
                 use_bias=True,kernel_initializer='glorot_uniform',bias_initializer='zeros',
                 kernel_regularizer=None,bias_regularizer=None,activity_regularizer=None,
                 kernel_constraint=None,bias_constraint=None,lrn2d_norm=LRN2D_NORM,weight_decay=WEIGHT_DECAY):
    #l2 normalization
    if weight_decay:
        kernel_regularizer=regularizers.l2(weight_decay)
        bias_regularizer=regularizers.l2(weight_decay)
    else:
        kernel_regularizer=None
        bias_regularizer=None
    x=Conv2D(filters=filters,kernel_size=kernel_size,padding=padding,
             activation=activation,use_bias=use_bias,kernel_initializer=kernel_initializer,
             bias_initializer=bias_initializer,kernel_regularizer=kernel_regularizer,bias_regularizer=bias_regularizer,
             activity_regularizer=activity_regularizer,kernel_constraint=kernel_constraint,bias_constraint=bias_constraint)(x)
    if lrn2d_norm:
        #batch normalization
        x=BatchNormalization()(x)

    return x

# %%
class VGG16:
    @staticmethod
    def build(width, height, depth, NB_CLASS):
        INP_SHAPE = (height, width, depth)
        img_input = Input(shape=INP_SHAPE)
        CONCAT_AXIS = 3
        # Data format:tensorflow,channels_last;theano,channels_last
        if K.image_data_format() == 'channels_first':
            INP_SHAPE = (depth, height, width)
            img_input = Input(shape=INP_SHAPE)
            CONCAT_AXIS = 1
        
        x = conv2D_lrn2d(img_input, 64, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 64, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same')(x)
        x = BatchNormalization()(x)

        x = conv2D_lrn2d(x, 128, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 128, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same')(x)
        x = BatchNormalization()(x)

        x = conv2D_lrn2d(x, 256, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 256, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 256, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same')(x)
        x = BatchNormalization()(x)

        x = conv2D_lrn2d(x, 512, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 512, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = conv2D_lrn2d(x, 512, (3, 3), padding='same',activation='relu', lrn2d_norm=False)
        x = MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='same')(x)
        x = BatchNormalization()(x)

        x = Flatten()(x)
        x = Dropout(DROPOUT)(x)
        x = Dense(4096, activation='relu')(x)
        x = Dense(4096, activation='relu')(x)
        x = Dense(output_dim=NB_CLASS, activation='softmax')(x)

        # Create a Keras Model
        model = Model(input=img_input, output=[x])
        model.summary()
        # Save a PNG of the Model Build
        # plot_model(model, to_file='../imgs/GoogLeNet.png')
        # return the constructed network architecture
        return model

# %%
import numpy as np
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras import backend as K
from keras.models import load_model

# %%
# load minit data
from keras.datasets import cifar100
(x_train, y_train),(x_test, y_test) = cifar100.load_data()

# %%
# plot 6 images as gray scale
import matplotlib.pyplot as plt

plt.subplot(321)
plt.imshow(x_train[0],cmap=plt.get_cmap('gray'))
plt.subplot(322)
plt.imshow(x_train[1],cmap=plt.get_cmap('gray'))
plt.subplot(323)
plt.imshow(x_train[2],cmap=plt.get_cmap('gray'))
plt.subplot(324)
plt.imshow(x_train[3],cmap=plt.get_cmap('gray'))
plt.subplot(325)
plt.imshow(x_train[4],cmap=plt.get_cmap('gray'))
plt.subplot(326)
plt.imshow(x_train[5],cmap=plt.get_cmap('gray'))
# show
plt.show()

# %%
print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0], 32, 32, 3).astype('float32')
x_test = x_test.reshape(x_test.shape[0], 32, 32, 3).astype('float32')

# normalization
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train, axis=(0, 1, 2, 3))
print(mean)
print(std)
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

# one-hot
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
# Out:
# (50000, 32, 32, 3)
# 121.93584
# 68.38902

# %%
y_train.shape
# Out:
# (50000, 100)

# %%
# parameters
EPOCHS = 50
INIT_LR = 1e-3
BS = 128
CLASS_NUM = 100
norm_size = 32
Depth = 3

# %%
# start to train model
print('start to train model')

model = VGG16.build(width=norm_size, height=norm_size, depth=Depth, NB_CLASS=CLASS_NUM)
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])


# Use generators to save memory
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,
                             height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                             horizontal_flip=True, fill_mode="nearest")

H = model.fit_generator(aug.flow(x_train, y_train, batch_size=BS),
                            steps_per_epoch=len(x_train) // BS, validation_data=aug.flow(x_test, y_test),
                            epochs=EPOCHS, verbose=2, use_multiprocessing=False)
# Out:
# start to train model
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              8392704
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               409700
# =================================================================
# Total params: 33,222,820
# Trainable params: 33,220,900
# Non-trainable params: 1,920
# _________________________________________________________________
# Epoch 1/50
#  - 48s - loss: 5.0401 - accuracy: 0.0509 - val_loss: 4.6765 - val_accuracy: 0.0753
# Epoch 2/50
#  - 40s - loss: 4.1416 - accuracy: 0.0961 - val_loss: 3.8187 - val_accuracy: 0.0976
# Epoch 3/50
#  - 40s - loss: 3.8441 - accuracy: 0.1245 - val_loss: 5.6350 - val_accuracy: 0.0513
# Epoch 4/50
#  - 40s - loss: 3.6718 - accuracy: 0.1525 - val_loss: 3.9313 - val_accuracy: 0.1362
# Epoch 5/50
#  - 40s - loss: 3.5236 - accuracy: 0.1797 - val_loss: 3.9660 - val_accuracy: 0.1718
# Epoch 6/50
#  - 40s - loss: 3.3690 - accuracy: 0.2113 - val_loss: 3.3715 - val_accuracy: 0.1746
# Epoch 7/50
#  - 41s - loss: 3.2234 - accuracy: 0.2432 - val_loss: 3.6895 - val_accuracy: 0.2332
# Epoch 8/50
#  - 40s - loss: 3.1196 - accuracy: 0.2655 - val_loss: 2.8059 - val_accuracy: 0.2442
# Epoch 9/50
#  - 41s - loss: 3.0180 - accuracy: 0.2916 - val_loss: 3.7063 - val_accuracy: 0.2577
# Epoch 10/50
#  - 41s - loss: 2.9417 - accuracy: 0.3101 - val_loss: 3.7150 - val_accuracy: 0.2329
# Epoch 11/50
#  - 41s - loss: 2.8599 - accuracy: 0.3297 - val_loss: 2.8537 - val_accuracy: 0.3025
# Epoch 12/50
#  - 41s - loss: 2.8063 - accuracy: 0.3459 - val_loss: 2.8962 - val_accuracy: 0.3282
# Epoch 13/50
#  - 40s - loss: 2.7458 - accuracy: 0.3603 - val_loss: 3.7557 - val_accuracy: 0.3158
# Epoch 14/50
#  - 42s - loss: 2.7017 - accuracy: 0.3739 - val_loss: 3.3239 - val_accuracy: 0.1749
# Epoch 15/50
#  - 40s - loss: 2.6488 - accuracy: 0.3907 - val_loss: 2.8414 - val_accuracy: 0.3611
# Epoch 16/50
#  - 41s - loss: 2.6158 - accuracy: 0.3990 - val_loss: 3.7296 - val_accuracy: 0.3291
# Epoch 17/50
#  - 41s - loss: 2.5749 - accuracy: 0.4112 - val_loss: 2.9669 - val_accuracy: 0.3588
# Epoch 18/50
#  - 40s - loss: 2.5264 - accuracy: 0.4218 - val_loss: 2.4333 - val_accuracy: 0.2894
# Epoch 19/50
#  - 40s - loss: 2.5036 - accuracy: 0.4282 - val_loss: 3.1576 - val_accuracy: 0.3549
# Epoch 20/50
#  - 40s - loss: 2.4616 - accuracy: 0.4358 - val_loss: 2.8717 - val_accuracy: 0.3714
# Epoch 21/50
#  - 40s - loss: 2.4450 - accuracy: 0.4458 - val_loss: 2.3735 - val_accuracy: 0.3956
# Epoch 22/50
#  - 41s - loss: 2.4198 - accuracy: 0.4499 - val_loss: 2.5172 - val_accuracy: 0.3834
# Epoch 23/50
#  - 41s - loss: 2.3925 - accuracy: 0.4571 - val_loss: 3.3590 - val_accuracy: 0.3790
# Epoch 24/50
#  - 41s - loss: 2.3819 - accuracy: 0.4628 - val_loss: 2.7541 - val_accuracy: 0.3919
# Epoch 25/50
#  - 42s - loss: 2.3451 - accuracy: 0.4712 - val_loss: 2.6355 - val_accuracy: 0.3717
# Epoch 26/50
#  - 41s - loss: 2.3338 - accuracy: 0.4742 - val_loss: 3.7718 - val_accuracy: 0.4278
# Epoch 27/50
#  - 40s - loss: 2.3012 - accuracy: 0.4826 - val_loss: 2.2923 - val_accuracy: 0.4216
# Epoch 28/50
#  - 41s - loss: 2.2893 - accuracy: 0.4869 - val_loss: 2.6956 - val_accuracy: 0.4261
# Epoch 29/50
#  - 40s - loss: 2.2499 - accuracy: 0.4946 - val_loss: 3.6151 - val_accuracy: 0.4322
# Epoch 30/50
#  - 40s - loss: 2.2518 - accuracy: 0.4959 - val_loss: 3.5169 - val_accuracy: 0.4471
# Epoch 31/50
#  - 41s - loss: 2.2464 - accuracy: 0.4986 - val_loss: 2.3594 - val_accuracy: 0.4358
# Epoch 32/50
#  - 40s - loss: 2.2217 - accuracy: 0.5013 - val_loss: 2.6870 - val_accuracy: 0.4171
# Epoch 33/50
#  - 41s - loss: 2.1957 - accuracy: 0.5073 - val_loss: 2.4429 - val_accuracy: 0.4313
# Epoch 34/50
#  - 40s - loss: 2.1799 - accuracy: 0.5114 - val_loss: 1.9892 - val_accuracy: 0.4522
# Epoch 35/50
#  - 41s - loss: 2.1796 - accuracy: 0.5123 - val_loss: 1.7062 - val_accuracy: 0.4530
# Epoch 36/50
#  - 40s - loss: 2.1554 - accuracy: 0.5196 - val_loss: 1.9487 - val_accuracy: 0.4621
# Epoch 37/50
#  - 41s - loss: 2.1467 - accuracy: 0.5210 - val_loss: 1.5467 - val_accuracy: 0.4545
# Epoch 38/50
#  - 40s - loss: 2.1277 - accuracy: 0.5251 - val_loss: 2.7189 - val_accuracy: 0.4536
# Epoch 39/50
#  - 40s - loss: 2.1250 - accuracy: 0.5228 - val_loss: 3.3081 - val_accuracy: 0.4608
# Epoch 40/50
#  - 40s - loss: 2.1042 - accuracy: 0.5313 - val_loss: 4.0169 - val_accuracy: 0.4539
# Epoch 41/50
#  - 41s - loss: 2.0903 - accuracy: 0.5315 - val_loss: 1.8681 - val_accuracy: 0.4609
# Epoch 42/50
#  - 42s - loss: 2.0678 - accuracy: 0.5386 - val_loss: 2.3991 - val_accuracy: 0.4708
# Epoch 43/50
#  - 42s - loss: 2.0563 - accuracy: 0.5392 - val_loss: 2.0694 - val_accuracy: 0.4534
# Epoch 44/50
#  - 42s - loss: 2.0510 - accuracy: 0.5432 - val_loss: 3.1966 - val_accuracy: 0.4502
# Epoch 45/50
#  - 42s - loss: 2.0269 - accuracy: 0.5469 - val_loss: 2.8211 - val_accuracy: 0.4777
# Epoch 46/50
#  - 41s - loss: 2.0373 - accuracy: 0.5500 - val_loss: 2.8096 - val_accuracy: 0.4563
# Epoch 47/50
#  - 40s - loss: 2.0199 - accuracy: 0.5528 - val_loss: 1.9074 - val_accuracy: 0.4406
# Epoch 48/50
#  - 41s - loss: 2.0017 - accuracy: 0.5536 - val_loss: 1.8366 - val_accuracy: 0.4853
# Epoch 49/50
#  - 41s - loss: 1.9916 - accuracy: 0.5559 - val_loss: 1.2902 - val_accuracy: 0.4845
# Epoch 50/50
#  - 40s - loss: 1.9914 - accuracy: 0.5606 - val_loss: 2.6580 - val_accuracy: 0.4732

# %%
# save model
# method one
model.save('VGG16_cifar100.h5')

# method two
# save model by json and weights
# save json
from keras.models import model_from_json
json_string = model.to_json()
with open(r'VGG16_cifar100.json', 'w') as file:
    file.write(json_string)

# save weights
model.save_weights('VGG16_cifar100.h5')

# %%
import json
# Get the dictionary containing each metric and the loss for each epoch
VGG16_cifar100_history_dict = H.history
# Save it under the form of a json file
json = json.dumps(str(VGG16_cifar100_history_dict))
f = open("VGG16_cifar100_history_dict.json","w")
f.write(json)
f.close()

# %%
import json 
data = {}
# Opening JSON file 
with open("VGG16_cifar100_history_dict.json") as json_file: 
    data = json.load(json_file)

# %%
print(type(data))
result_dict = eval(data)
print(result_dict.keys())
# Out:
# <class 'str'>
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(result_dict['accuracy'])
plt.plot(result_dict['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(result_dict['loss'])
plt.plot(result_dict['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
nb_epoch = EPOCHS

fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,nb_epoch+1), result_dict['val_loss'])
ax1.set(xlabel='Epochs', ylabel='Validation Loss',
       title='Epochs vs. Validation Loss')
ax2.plot(np.arange(1,nb_epoch+1), result_dict['loss'])
ax2.set(xlabel='Epochs', ylabel='Training Loss',
       title='Epochs vs. Training Loss')
plt.show()

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,nb_epoch+1), result_dict['val_accuracy'])
ax1.set(xlabel='Epochs', ylabel='Validation Accuracy',
       title='Epochs vs. Validation Accuracy')
ax2.plot(np.arange(1,nb_epoch+1), result_dict['accuracy'])
ax2.set(xlabel='Epochs', ylabel='Training Accuracy',
       title='Epochs vs. Training Accuracy')
plt.show()

# %%
# import tensorflow as tf

# %%
predictions = model.predict(x_test, verbose=0)

# %%
np.argmax(y_test[0])
# Out:
# 49

# %%
def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if np.argmax(predictions[i]) == np.argmax(y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 50.13 %

# %%
x_test[0].shape
# plt.imshow(x_train[0],cmap=plt.get_cmap('gray'))
# Out:
# (32, 32, 3)

# %%
print(p[2][2])
# Out:
# 4

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test[p[2][i]].reshape(32,32,3), interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test[p[2][i+6]].reshape(32,32,3), interpolation='none', cmap=plt.cm.gray)
plt.show()

# print("True:          {}".format(y_test[p[2][0:5]]))
print("True classification as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

# print("True:          {}".format(y_test[p[2][6:11]]))
print("True classification as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# True classification as: [68  4 23 79  8]
# True classification as: [57 12 32 39 48]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
